# %% [markdown]
# <a href="https://colab.research.google.com/github/NamitNaik/Neural-Networks-and-Fuzzy-Logic/blob/master/BPN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

X = np.array(([0, 0], [0, 1], [1, 0],[1, 1]), dtype=float)
t = np.array(([0], [1], [1], [1]), dtype=float)


class Neural_Network():
  def __init__(self):
    #parameters
    self.inputSize = 2
    self.outputSize = 1
    self.hiddenSize = 2
    #weights
    #np.random.seed(0)
    self.W1 = np.random.randn(self.inputSize, self.hiddenSize) 
    self.W2 = np.random.randn(self.hiddenSize, self.outputSize)
   

  def forward(self, X):
    
    self.zin = np.dot(X, self.W1)
    self.z = self.sigmoid(self.zin)
    self.yin = np.dot(self.z, self.W2) 
    y = self.sigmoid(self.yin) 
    return y

  def sigmoid(self, s):  
    return 1/(1+np.exp(-s))

  def sigmoidPrime(self, s):
    return s * (1 - s)

  def backward(self, X, t, y):
    self.y_error = t - y 
    self.y_delta = self.y_error*self.sigmoidPrime(y)

    self.z_error = self.y_delta.dot(self.W2.T) 
    self.z_delta = self.z_error*self.sigmoidPrime(self.z) 

    self.W1 += X.T.dot(self.z_delta) 
    self.W2 += self.z.T.dot(self.y_delta) 

  

NN = Neural_Network()
for i in range(1000):
  print("iteration:",i)
  print("Input: \n" + str(X))
  print("Actual Output: \n" + str(t))
  y=NN.forward(X)
  print("Predicted Output: \n" + str(y))
  Loss=np.mean(np.square(t - NN.forward(X)))
  print("Loss: \n" + str(Loss))
  if Loss<=0.02:
    break
  print("\n")
  NN.backward(X, t, y)
# Out:
# iteration: 0
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.14599315]
#  [0.14769561]
#  [0.08652741]
#  [0.08812534]]
# Loss:
# 0.6034210859763504
#
#
# iteration: 1
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.16496659]
#  [0.17718707]
#  [0.10809241]
#  [0.1168725 ]]
# Loss:
# 0.5699121064066814
#
#
# iteration: 2
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.18887215]
#  [0.21346713]
#  [0.1375255 ]
#  [0.15688073]]
# Loss:
# 0.5272547576982914
#
#
# iteration: 3
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.21857648]
#  [0.25636772]
#  [0.17680612]
#  [0.20978851]]
# Loss:
# 0.47571175315006764
#
#
# iteration: 4
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.254138  ]
#  [0.30402756]
#  [0.22643102]
#  [0.27365916]]
# Loss:
# 0.4187359334021359
#
#
# iteration: 5
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.29413808]
#  [0.3530322 ]
#  [0.28395582]
#  [0.34224851]]
# Loss:
# 0.36261020683610407
#
#
# iteration: 6
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.33579577]
#  [0.39988357]
#  [0.34440143]
#  [0.40836853]]
# Loss:
# 0.313183950385241
#
#
# iteration: 7
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.37608821]
#  [0.44247246]
#  [0.40274563]
#  [0.46782946]]
# Loss:
# 0.27304939117735594
#
#
# iteration: 8
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.41283022]
#  [0.48020657]
#  [0.45583243]
#  [0.51971957]]
# Loss:
# 0.24185040727096468
#
#
# iteration: 9
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.4449515 ]
#  [0.51333105]
#  [0.50243396]
#  [0.56464752]]
# Loss:
# 0.2179830636864883
#
#
# iteration: 10
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.47223141]
#  [0.5423574 ]
#  [0.54250874]
#  [0.60350385]]
# Loss:
# 0.19973667452892807
#
#
# iteration: 11
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.49493863]
#  [0.56780801]
#  [0.57657175]
#  [0.63707149]]
# Loss:
# 0.18569068756994098
#
#
# iteration: 12
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.51356391]
#  [0.59014733]
#  [0.60534328]
#  [0.66601096]]
# Loss:
# 0.17475742710886866
#
#
# iteration: 13
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.52866064]
#  [0.60977985]
#  [0.62957863]
#  [0.69091172]]
# Loss:
# 0.16612534883332836
#
#
# iteration: 14
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.54076197]
#  [0.62706034]
#  [0.64998837]
#  [0.71231857]]
# Loss:
# 0.15919406151714116
#
#
# iteration: 15
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.55034396]
#  [0.64230131]
#  [0.66720366]
#  [0.73073281]]
# Loss:
# 0.15352126328631058
#
#
# iteration: 16
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.55781443]
#  [0.65577731]
#  [0.6817657 ]
#  [0.74660513]]
# Loss:
# 0.14878205783656226
#
#
# iteration: 17
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.56351467]
#  [0.66772785]
#  [0.69412832]
#  [0.76033049]]
# Loss:
# 0.14473813099855212
#
#
# iteration: 18
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.56772682]
#  [0.67836036]
#  [0.70466704]
#  [0.77224778]]
# Loss:
# 0.14121460809608183
#
#
# iteration: 19
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.57068292]
#  [0.68785344]
#  [0.71369033]
#  [0.78264346]]
# Loss:
# 0.13808288900809884
#
#
# iteration: 20
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.57257373]
#  [0.69636031]
#  [0.72145098]
#  [0.79175739]]
# Loss:
# 0.13524806815713167
#
#
# iteration: 21
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.57355647]
#  [0.70401215]
#  [0.72815622]
#  [0.7997893 ]]
# Loss:
# 0.13263979672096968
#
#
# iteration: 22
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.57376132]
#  [0.71092127]
#  [0.73397639]
#  [0.80690523]]
# Loss:
# 0.1302056785995182
#
#
# iteration: 23
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.57329673]
#  [0.71718387]
#  [0.73905212]
#  [0.81324317]]
# Loss:
# 0.12790650436252735
#
#
# iteration: 24
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.57225364]
#  [0.72288257]
#  [0.74350001]
#  [0.81891801]]
# Loss:
# 0.12571280643822313
#
#
# iteration: 25
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.57070883]
#  [0.72808842]
#  [0.74741732]
#  [0.82402569]]
# Loss:
# 0.12360236002099803
#
#
# iteration: 26
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.56872762]
#  [0.73286272]
#  [0.75088556]
#  [0.82864655]]
# Loss:
# 0.12155836052537877
#
#
# iteration: 27
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.56636595]
#  [0.73725848]
#  [0.75397341]
#  [0.83284809]]
# Loss:
# 0.11956808608338033
#
#
# iteration: 28
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.56367207]
#  [0.74132164]
#  [0.75673904]
#  [0.83668728]]
# Loss:
# 0.11762190922838908
#
#
# iteration: 29
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.56068785]
#  [0.74509217]
#  [0.75923191]
#  [0.84021231]]
# Loss:
# 0.11571256133753219
#
#
# iteration: 30
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.55744985]
#  [0.74860486]
#  [0.76149425]
#  [0.84346413]]
# Loss:
# 0.11383458119351114
#
#
# iteration: 31
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.55399019]
#  [0.75189009]
#  [0.76356223]
#  [0.84647762]]
# Loss:
# 0.11198389858618778
#
#
# iteration: 32
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.5503372 ]
#  [0.75497444]
#  [0.76546691]
#  [0.84928259]]
# Loss:
# 0.11015751766140161
#
#
# iteration: 33
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.54651602]
#  [0.75788118]
#  [0.76723499]
#  [0.85190455]]
# Loss:
# 0.10835327447661348
#
#
# iteration: 34
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.54254902]
#  [0.76063069]
#  [0.76888949]
#  [0.85436544]]
# Loss:
# 0.10656965015444245
#
#
# iteration: 35
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.53845621]
#  [0.76324091]
#  [0.77045022]
#  [0.8566841 ]]
# Loss:
# 0.10480562598053353
#
#
# iteration: 36
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.5342555 ]
#  [0.76572753]
#  [0.77193423]
#  [0.85887679]]
# Loss:
# 0.10306057035783783
#
#
# iteration: 37
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.52996302]
#  [0.7681044 ]
#  [0.77335618]
#  [0.86095753]]
# Loss:
# 0.10133415011279037
#
#
# iteration: 38
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.5255933 ]
#  [0.77038364]
#  [0.77472864]
#  [0.86293845]]
# Loss:
# 0.0996262605339929
#
#
# iteration: 39
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.52115946]
#  [0.77257592]
#  [0.77606236]
#  [0.86483004]]
# Loss:
# 0.09793696990946811
#
#
# iteration: 40
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.51667338]
#  [0.77469061]
#  [0.77736648]
#  [0.86664138]]
# Loss:
# 0.09626647535398045
#
#
# iteration: 41
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.51214581]
#  [0.77673595]
#  [0.77864876]
#  [0.86838035]]
# Loss:
# 0.09461506748200113
#
#
# iteration: 42
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.50758651]
#  [0.77871915]
#  [0.77991568]
#  [0.8700538 ]]
# Loss:
# 0.09298310205483475
#
#
# iteration: 43
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.50300435]
#  [0.78064653]
#  [0.78117268]
#  [0.87166765]]
# Loss:
# 0.09137097716247351
#
#
# iteration: 44
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.49840738]
#  [0.78252366]
#  [0.78242423]
#  [0.87322708]]
# Loss:
# 0.08977911482817613
#
#
# iteration: 45
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.4938029 ]
#  [0.78435537]
#  [0.78367397]
#  [0.87473658]]
# Loss:
# 0.0882079461729322
#
#
# iteration: 46
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.48919757]
#  [0.78614591]
#  [0.78492479]
#  [0.87620008]]
# Loss:
# 0.08665789946720773
#
#
# iteration: 47
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.48459743]
#  [0.78789899]
#  [0.78617897]
#  [0.877621  ]]
# Loss:
# 0.08512939054296323
#
#
# iteration: 48
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.48000798]
#  [0.78961784]
#  [0.78743823]
#  [0.87900233]]
# Loss:
# 0.08362281515056028
#
#
# iteration: 49
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.4754342 ]
#  [0.79130526]
#  [0.78870381]
#  [0.88034669]]
# Loss:
# 0.0821385429308469
#
#
# iteration: 50
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.47088062]
#  [0.7929637 ]
#  [0.78997652]
#  [0.88165641]]
# Loss:
# 0.0806769127385262
#
#
# iteration: 51
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.46635132]
#  [0.79459529]
#  [0.79125685]
#  [0.8829335 ]]
# Loss:
# 0.07923822910351187
#
#
# iteration: 52
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.46185002]
#  [0.79620187]
#  [0.79254496]
#  [0.88417976]]
# Loss:
# 0.07782275965592826
#
#
# iteration: 53
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.45738006]
#  [0.79778502]
#  [0.79384079]
#  [0.8853968 ]]
# Loss:
# 0.07643073337047518
#
#
# iteration: 54
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.45294446]
#  [0.79934612]
#  [0.79514404]
#  [0.88658601]]
# Loss:
# 0.07506233950917525
#
#
# iteration: 55
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.44854592]
#  [0.80088637]
#  [0.79645425]
#  [0.88774869]]
# Loss:
# 0.07371772715969525
#
#
# iteration: 56
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.44418687]
#  [0.80240677]
#  [0.79777084]
#  [0.88888595]]
# Loss:
# 0.07239700528075232
#
#
# iteration: 57
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.43986946]
#  [0.80390822]
#  [0.79909309]
#  [0.88999883]]
# Loss:
# 0.07110024317754844
#
#
# iteration: 58
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.43559562]
#  [0.80539146]
#  [0.8004202 ]
#  [0.89108827]]
# Loss:
# 0.06982747133946818
#
#
# iteration: 59
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.43136703]
#  [0.80685714]
#  [0.80175134]
#  [0.89215511]]
# Loss:
# 0.06857868257997776
#
#
# iteration: 60
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.42718518]
#  [0.80830582]
#  [0.80308559]
#  [0.89320013]]
# Loss:
# 0.06735383342520022
#
#
# iteration: 61
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.42305137]
#  [0.80973797]
#  [0.80442205]
#  [0.89422406]]
# Loss:
# 0.06615284570331348
#
#
# iteration: 62
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.41896668]
#  [0.811154  ]
#  [0.80575976]
#  [0.89522755]]
# Loss:
# 0.06497560829194873
#
#
# iteration: 63
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.41493209]
#  [0.81255425]
#  [0.8070978 ]
#  [0.89621123]]
# Loss:
# 0.06382197898531031
#
#
# iteration: 64
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.41094836]
#  [0.81393901]
#  [0.80843523]
#  [0.89717567]]
# Loss:
# 0.06269178644689971
#
#
# iteration: 65
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.40701614]
#  [0.81530856]
#  [0.80977115]
#  [0.89812142]]
# Loss:
# 0.06158483221757983
#
#
# iteration: 66
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.40313596]
#  [0.8166631 ]
#  [0.81110467]
#  [0.899049  ]]
# Loss:
# 0.06050089275230131
#
#
# iteration: 67
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.3993082 ]
#  [0.81800283]
#  [0.81243494]
#  [0.89995888]]
# Loss:
# 0.05943972146216049
#
#
# iteration: 68
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.39553314]
#  [0.81932791]
#  [0.81376113]
#  [0.90085155]]
# Loss:
# 0.05840105074158129
#
#
# iteration: 69
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.39181096]
#  [0.82063848]
#  [0.81508245]
#  [0.90172743]]
# Loss:
# 0.05738459396331942
#
#
# iteration: 70
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.38814173]
#  [0.82193468]
#  [0.81639817]
#  [0.90258695]]
# Loss:
# 0.056390047426678906
#
#
# iteration: 71
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.38452545]
#  [0.82321663]
#  [0.81770759]
#  [0.90343053]]
# Loss:
# 0.05541709224681227
#
#
# iteration: 72
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.38096203]
#  [0.82448442]
#  [0.81901003]
#  [0.90425854]]
# Loss:
# 0.05446539617524362
#
#
# iteration: 73
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.37745131]
#  [0.82573815]
#  [0.82030489]
#  [0.90507137]]
# Loss:
# 0.05353461534381845
#
#
# iteration: 74
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.37399306]
#  [0.82697792]
#  [0.82159158]
#  [0.90586938]]
# Loss:
# 0.052624395926140176
#
#
# iteration: 75
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.37058698]
#  [0.82820382]
#  [0.82286958]
#  [0.90665292]]
# Loss:
# 0.051734375712215334
#
#
# iteration: 76
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.36723274]
#  [0.82941592]
#  [0.82413839]
#  [0.90742235]]
# Loss:
# 0.05086418559349791
#
#
# iteration: 77
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.36392994]
#  [0.83061432]
#  [0.82539757]
#  [0.90817798]]
# Loss:
# 0.05001345095681274
#
#
# iteration: 78
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.36067813]
#  [0.83179909]
#  [0.8266467 ]
#  [0.90892014]]
# Loss:
# 0.049181792986753535
#
#
# iteration: 79
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.35747684]
#  [0.83297032]
#  [0.8278854 ]
#  [0.90964914]]
# Loss:
# 0.04836882987710797
#
#
# iteration: 80
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.35432555]
#  [0.83412809]
#  [0.82911336]
#  [0.91036529]]
# Loss:
# 0.04757417795266999
#
#
# iteration: 81
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.35122371]
#  [0.83527249]
#  [0.83033026]
#  [0.91106888]]
# Loss:
# 0.046797452703472665
#
#
# iteration: 82
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.34817073]
#  [0.8364036 ]
#  [0.83153583]
#  [0.9117602 ]]
# Loss:
# 0.04603826973402165
#
#
# iteration: 83
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.34516603]
#  [0.83752153]
#  [0.83272985]
#  [0.91243952]]
# Loss:
# 0.04529624563054855
#
#
# iteration: 84
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.34220897]
#  [0.83862635]
#  [0.8339121 ]
#  [0.91310714]]
# Loss:
# 0.044570998749639414
#
#
# iteration: 85
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.33929892]
#  [0.83971818]
#  [0.83508241]
#  [0.9137633 ]]
# Loss:
# 0.04386214993184525
#
#
# iteration: 86
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.33643521]
#  [0.84079709]
#  [0.83624062]
#  [0.91440826]]
# Loss:
# 0.04316932314405406
#
#
# iteration: 87
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.33361717]
#  [0.84186321]
#  [0.83738663]
#  [0.91504229]]
# Loss:
# 0.04249214605451032
#
#
# iteration: 88
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.33084413]
#  [0.84291663]
#  [0.83852031]
#  [0.91566562]]
# Loss:
# 0.04183025054441829
#
#
# iteration: 89
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.32811539]
#  [0.84395745]
#  [0.8396416 ]
#  [0.9162785 ]]
# Loss:
# 0.041183273160064954
#
#
# iteration: 90
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.32543026]
#  [0.8449858 ]
#  [0.84075044]
#  [0.91688116]]
# Loss:
# 0.040550855509361015
#
#
# iteration: 91
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.32278803]
#  [0.84600178]
#  [0.84184678]
#  [0.91747383]]
# Loss:
# 0.03993264460662348
#
#
# iteration: 92
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.32018801]
#  [0.84700551]
#  [0.8429306 ]
#  [0.91805673]]
# Loss:
# 0.0393282931693244
#
#
# iteration: 93
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.31762948]
#  [0.8479971 ]
#  [0.84400191]
#  [0.91863007]]
# Loss:
# 0.03873745987040862
#
#
# iteration: 94
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.31511175]
#  [0.84897668]
#  [0.8450607 ]
#  [0.91919408]]
# Loss:
# 0.03815980954964551
#
#
# iteration: 95
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.3126341 ]
#  [0.84994437]
#  [0.84610701]
#  [0.91974894]]
# Loss:
# 0.03759501338732886
#
#
# iteration: 96
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.31019583]
#  [0.8509003 ]
#  [0.84714087]
#  [0.92029488]]
# Loss:
# 0.03704274904348141
#
#
# iteration: 97
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.30779626]
#  [0.85184458]
#  [0.84816234]
#  [0.92083208]]
# Loss:
# 0.036502700765555306
#
#
# iteration: 98
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.30543468]
#  [0.85277735]
#  [0.84917146]
#  [0.92136073]]
# Loss:
# 0.03597455946745389
#
#
# iteration: 99
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.30311041]
#  [0.85369873]
#  [0.85016831]
#  [0.92188102]]
# Loss:
# 0.035458022782532905
#
#
# iteration: 100
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.30082276]
#  [0.85460886]
#  [0.85115297]
#  [0.92239313]]
# Loss:
# 0.03495279509307292
#
#
# iteration: 101
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.29857106]
#  [0.85550787]
#  [0.85212552]
#  [0.92289724]]
# Loss:
# 0.034458587538553374
#
#
# iteration: 102
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.29635464]
#  [0.85639588]
#  [0.85308607]
#  [0.92339352]]
# Loss:
# 0.033975118004898476
#
#
# iteration: 103
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.29417284]
#  [0.85727304]
#  [0.85403471]
#  [0.92388214]]
# Loss:
# 0.033502111096713263
#
#
# iteration: 104
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.29202502]
#  [0.85813947]
#  [0.85497154]
#  [0.92436327]]
# Loss:
# 0.03303929809437934
#
#
# iteration: 105
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.28991052]
#  [0.8589953 ]
#  [0.85589668]
#  [0.92483706]]
# Loss:
# 0.03258641689773968
#
#
# iteration: 106
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.28782871]
#  [0.85984068]
#  [0.85681025]
#  [0.92530367]]
# Loss:
# 0.0321432119579661
#
#
# iteration: 107
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.28577897]
#  [0.86067574]
#  [0.85771236]
#  [0.92576325]]
# Loss:
# 0.03170943419907683
#
#
# iteration: 108
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.28376069]
#  [0.86150061]
#  [0.85860315]
#  [0.92621596]]
# Loss:
# 0.03128484093044999
#
#
# iteration: 109
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.28177325]
#  [0.86231542]
#  [0.85948273]
#  [0.92666193]]
# Loss:
# 0.03086919575156565
#
#
# iteration: 110
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.27981606]
#  [0.8631203 ]
#  [0.86035124]
#  [0.92710131]]
# Loss:
# 0.030462268450102782
#
#
# iteration: 111
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.27788854]
#  [0.8639154 ]
#  [0.86120882]
#  [0.92753424]]
# Loss:
# 0.030063834894417697
#
#
# iteration: 112
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.27599012]
#  [0.86470084]
#  [0.86205559]
#  [0.92796084]]
# Loss:
# 0.029673676921337044
#
#
# iteration: 113
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.27412022]
#  [0.86547676]
#  [0.86289169]
#  [0.92838126]]
# Loss:
# 0.0292915822201127
#
#
# iteration: 114
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.27227829]
#  [0.86624328]
#  [0.86371726]
#  [0.92879562]]
# Loss:
# 0.028917344213304216
#
#
# iteration: 115
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.2704638 ]
#  [0.86700055]
#  [0.86453244]
#  [0.92920404]]
# Loss:
# 0.028550761935281572
#
#
# iteration: 116
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.26867619]
#  [0.86774867]
#  [0.86533736]
#  [0.92960664]]
# Loss:
# 0.028191639908970206
#
#
# iteration: 117
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.26691496]
#  [0.8684878 ]
#  [0.86613218]
#  [0.93000355]]
# Loss:
# 0.02783978802139812
#
#
# iteration: 118
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.26517958]
#  [0.86921805]
#  [0.86691701]
#  [0.93039488]]
# Loss:
# 0.027495021398545528
#
#
# iteration: 119
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.26346956]
#  [0.86993955]
#  [0.86769201]
#  [0.93078074]]
# Loss:
# 0.02715716027994363
#
#
# iteration: 120
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.2617844 ]
#  [0.87065242]
#  [0.86845732]
#  [0.93116124]]
# Loss:
# 0.026826029893420283
#
#
# iteration: 121
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.26012361]
#  [0.8713568 ]
#  [0.86921306]
#  [0.93153649]]
# Loss:
# 0.026501460330343903
#
#
# iteration: 122
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.25848673]
#  [0.8720528 ]
#  [0.86995939]
#  [0.9319066 ]]
# Loss:
# 0.02618328642167661
#
#
# iteration: 123
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.25687328]
#  [0.87274055]
#  [0.87069643]
#  [0.93227167]]
# Loss:
# 0.02587134761510936
#
#
# iteration: 124
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.25528282]
#  [0.87342017]
#  [0.87142433]
#  [0.93263179]]
# Loss:
# 0.02556548785351679
#
#
# iteration: 125
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.2537149 ]
#  [0.87409177]
#  [0.87214323]
#  [0.93298706]]
# Loss:
# 0.02526555545493936
#
#
# iteration: 126
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.25216908]
#  [0.87475548]
#  [0.87285324]
#  [0.93333758]]
# Loss:
# 0.02497140299427054
#
#
# iteration: 127
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.25064494]
#  [0.87541141]
#  [0.87355452]
#  [0.93368345]]
# Loss:
# 0.024682887186802015
#
#
# iteration: 128
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.24914206]
#  [0.87605967]
#  [0.87424718]
#  [0.93402475]]
# Loss:
# 0.024399868773755676
#
#
# iteration: 129
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.24766003]
#  [0.87670039]
#  [0.87493137]
#  [0.93436156]]
# Loss:
# 0.024122212409910755
#
#
# iteration: 130
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.24619845]
#  [0.87733367]
#  [0.87560721]
#  [0.93469399]]
# Loss:
# 0.02384978655341488
#
#
# iteration: 131
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.24475693]
#  [0.87795962]
#  [0.87627483]
#  [0.9350221 ]]
# Loss:
# 0.023582463357850924
#
#
# iteration: 132
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.24333509]
#  [0.87857835]
#  [0.87693436]
#  [0.93534599]]
# Loss:
# 0.023320118566616057
#
#
# iteration: 133
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.24193255]
#  [0.87918998]
#  [0.87758591]
#  [0.93566573]]
# Loss:
# 0.023062631409655806
#
#
# iteration: 134
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.24054895]
#  [0.8797946 ]
#  [0.87822963]
#  [0.9359814 ]]
# Loss:
# 0.022809884502583186
#
#
# iteration: 135
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.23918393]
#  [0.88039233]
#  [0.87886562]
#  [0.93629308]]
# Loss:
# 0.02256176374820251
#
#
# iteration: 136
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.23783713]
#  [0.88098327]
#  [0.87949401]
#  [0.93660085]]
# Loss:
# 0.022318158240447326
#
#
# iteration: 137
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.23650823]
#  [0.88156751]
#  [0.88011491]
#  [0.93690477]]
# Loss:
# 0.022078960170733488
#
#
# iteration: 138
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.23519687]
#  [0.88214516]
#  [0.88072845]
#  [0.93720491]]
# Loss:
# 0.02184406473672062
#
#
# iteration: 139
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.23390274]
#  [0.88271631]
#  [0.88133473]
#  [0.93750135]]
# Loss:
# 0.02161337005346851
#
#
# iteration: 140
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.23262551]
#  [0.88328108]
#  [0.88193388]
#  [0.93779416]]
# Loss:
# 0.021386777066969464
#
#
# iteration: 141
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.23136487]
#  [0.88383954]
#  [0.88252601]
#  [0.9380834 ]]
# Loss:
# 0.021164189470031763
#
#
# iteration: 142
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.23012051]
#  [0.8843918 ]
#  [0.88311122]
#  [0.93836913]]
# Loss:
# 0.02094551362048562
#
#
# iteration: 143
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.22889213]
#  [0.88493795]
#  [0.88368962]
#  [0.93865142]]
# Loss:
# 0.02073065846167919
#
#
# iteration: 144
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.22767944]
#  [0.88547808]
#  [0.88426132]
#  [0.93893033]]
# Loss:
# 0.020519535445228134
#
#
# iteration: 145
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.22648215]
#  [0.88601228]
#  [0.88482643]
#  [0.93920593]]
# Loss:
# 0.02031205845598086
#
#
# iteration: 146
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.22529998]
#  [0.88654064]
#  [0.88538504]
#  [0.93947826]]
# Loss:
# 0.020108143739157636
#
#
# iteration: 147
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.22413265]
#  [0.88706325]
#  [0.88593727]
#  [0.9397474 ]]
# Loss:
# 0.019907709829621426

# %%
import numpy as np

X = np.array(([0, 0], [0, 1], [1, 0],[1, 1]), dtype=float)
t = np.array(([0], [1], [1], [1]), dtype=float)


class Neural_Network():
  def __init__(self):
    #parameters
    self.inputSize = 2
    self.outputSize = 1
    self.hiddenSize = 2
    #weights
    self.W1 = np.random.randn(self.inputSize, self.hiddenSize) 
    self.W2 = np.random.randn(self.hiddenSize, self.outputSize)
   

  def forward(self, X):
    
    self.zin = np.dot(X, self.W1)
    self.z = self.sigmoid(self.zin)
    self.yin = np.dot(self.z, self.W2) 
    y = self.sigmoid(self.yin) 
    return y

  def sigmoid(self, s):  
    return 1/(1+np.exp(-s))

  def sigmoidPrime(self, s):
    return s * (1 - s)

  def backward(self, X, t, y):
    self.y_error = t - y 
    self.y_delta = self.y_error*self.sigmoidPrime(y)

    self.z_error = self.y_delta.dot(self.W2.T) 
    self.z_delta = self.z_error*self.sigmoidPrime(self.z) 

    self.W1 += X.T.dot(self.z_delta) 
    self.W2 += self.z.T.dot(self.y_delta) 

  

NN = Neural_Network()
for i in range(1000):
  print("iteration:",i)
  print("Input: \n" + str(X))
  print("Actual Output: \n" + str(t))
  y=NN.forward(X)
  print("Predicted Output: \n" + str(y))
  Loss=np.mean(np.square(t - NN.forward(X)))
  print("Loss: \n" + str(Loss))
  if Loss<=0.06:
    break
  print("\n")
  NN.backward(X, t, y)
# Out:
# iteration: 0
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.24576318]
#  [0.26682368]
#  [0.2185072 ]
#  [0.24698366]]
# Loss:
# 0.4439279176645603
#
#
# iteration: 1
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.29051544]
#  [0.33488878]
#  [0.28325853]
#  [0.33081739]]
# Loss:
# 0.37207396106154594
#
#
# iteration: 2
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.33961156]
#  [0.40809495]
#  [0.35588706]
#  [0.42156519]]
# Loss:
# 0.3037889754776625
#
#
# iteration: 3
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.38741184]
#  [0.47752376]
#  [0.42699027]
#  [0.50627496]]
# Loss:
# 0.24879347919884892
#
#
# iteration: 4
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.4291489 ]
#  [0.5368722 ]
#  [0.48908238]
#  [0.57679963]]
# Loss:
# 0.20969787688725594
#
#
# iteration: 5
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.46299565]
#  [0.58455911]
#  [0.5396526 ]
#  [0.63191283]]
# Loss:
# 0.18359099931490835
#
#
# iteration: 6
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.48938435]
#  [0.62194308]
#  [0.57962685]
#  [0.67405937]]
# Loss:
# 0.16634373970946445
#
#
# iteration: 7
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.5095975 ]
#  [0.65119328]
#  [0.61105613]
#  [0.70636796]]
# Loss:
# 0.15471321235380836
#
#
# iteration: 8
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.52495642]
#  [0.67428447]
#  [0.63593066]
#  [0.73146806]]
# Loss:
# 0.1465814328362364
#
#
# iteration: 9
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.53655535]
#  [0.69275236]
#  [0.65584299]
#  [0.75130457]]
# Loss:
# 0.1406465538805526
#
#
# iteration: 10
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.54523494]
#  [0.70772876]
#  [0.67198661]
#  [0.76725855]]
# Loss:
# 0.13611624700429437
#
#
# iteration: 11
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.55162582]
#  [0.72003657]
#  [0.68523912]
#  [0.78030466]]
# Loss:
# 0.13250275674880488
#
#
# iteration: 12
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.55620006]
#  [0.73027633]
#  [0.69624632]
#  [0.7911366 ]]
# Loss:
# 0.12949989507511483
#
#
# iteration: 13
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.55931375]
#  [0.73889124]
#  [0.70548792]
#  [0.80025533]]
# Loss:
# 0.12691123668423152
#
#
# iteration: 14
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.5612387 ]
#  [0.74621299]
#  [0.71332488]
#  [0.80802867]]
# Loss:
# 0.12460808379543938
#
#
# iteration: 15
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.56218522]
#  [0.75249359]
#  [0.72003263]
#  [0.81473121]]
# Loss:
# 0.12250447375754112
#
#
# iteration: 16
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.56231831]
#  [0.75792727]
#  [0.72582436]
#  [0.82057126]]
# Loss:
# 0.12054201195339243
#
#
# iteration: 17
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.56176917]
#  [0.76266584]
#  [0.73086721]
#  [0.82570918]]
# Loss:
# 0.11868046313939871
#
#
# iteration: 18
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.56064348]
#  [0.76682946]
#  [0.73529393]
#  [0.83027013]]
# Loss:
# 0.1168917867445726
#
#
# iteration: 19
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.5590274 ]
#  [0.77051436]
#  [0.73921106]
#  [0.83435297]]
# Loss:
# 0.11515627628399341
#
#
# iteration: 20
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.55699199]
#  [0.77379842]
#  [0.74270506]
#  [0.83803665]]
# Loss:
# 0.11346001166042449
#
#
# iteration: 21
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.55459647]
#  [0.7767453 ]
#  [0.74584666]
#  [0.84138486]]
# Loss:
# 0.11179314734815425
#
#
# iteration: 22
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.55189065]
#  [0.77940741]
#  [0.74869421]
#  [0.84444939]]
# Loss:
# 0.11014874296148648
#
#
# iteration: 23
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.54891682]
#  [0.78182829]
#  [0.75129615]
#  [0.84727269]]
# Loss:
# 0.1085219520466624
#
#
# iteration: 24
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.54571118]
#  [0.78404432]
#  [0.75369292]
#  [0.84988978]]
# Loss:
# 0.10690945137646764
#
#
# iteration: 25
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.54230495]
#  [0.78608606]
#  [0.75591847]
#  [0.85232973]]
# Loss:
# 0.10530903417513633
#
#
# iteration: 26
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.53872523]
#  [0.78797933]
#  [0.75800135]
#  [0.85461676]]
# Loss:
# 0.10371931665079556
#
#
# iteration: 27
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.53499569]
#  [0.78974603]
#  [0.75996568]
#  [0.85677116]]
# Loss:
# 0.10213952385990983
#
#
# iteration: 28
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.53113714]
#  [0.79140477]
#  [0.76183182]
#  [0.85881   ]]
# Loss:
# 0.10056933178115875
#
#
# iteration: 29
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.52716795]
#  [0.79297147]
#  [0.76361702]
#  [0.86074763]]
# Loss:
# 0.09900874965941286
#
#
# iteration: 30
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.52310444]
#  [0.79445971]
#  [0.76533585]
#  [0.86259622]]
# Loss:
# 0.0974580315024958
#
#
# iteration: 31
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.51896114]
#  [0.79588115]
#  [0.76700064]
#  [0.86436606]]
# Loss:
# 0.09591760889325382
#
#
# iteration: 32
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.51475104]
#  [0.79724576]
#  [0.76862175]
#  [0.86606588]]
# Loss:
# 0.09438803953765923
#
#
# iteration: 33
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.51048582]
#  [0.79856212]
#  [0.77020791]
#  [0.86770312]]
# Loss:
# 0.09286996754194585
#
#
# iteration: 34
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.506176  ]
#  [0.79983757]
#  [0.7717664 ]
#  [0.86928409]]
# Loss:
# 0.09136409251764029
#
#
# iteration: 35
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.50183106]
#  [0.80107842]
#  [0.77330328]
#  [0.87081419]]
# Loss:
# 0.08987114539827157
#
#
# iteration: 36
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.49745959]
#  [0.80229006]
#  [0.77482357]
#  [0.87229803]]
# Loss:
# 0.08839186941314382
#
#
# iteration: 37
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.49306937]
#  [0.80347712]
#  [0.77633133]
#  [0.87373956]]
# Loss:
# 0.08692700506816985
#
#
# iteration: 38
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.48866749]
#  [0.80464353]
#  [0.77782988]
#  [0.87514214]]
# Loss:
# 0.08547727827698108
#
#
# iteration: 39
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.48426037]
#  [0.80579263]
#  [0.77932184]
#  [0.87650867]]
# Loss:
# 0.08404339099905583
#
#
# iteration: 40
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.47985386]
#  [0.80692728]
#  [0.78080924]
#  [0.87784165]]
# Loss:
# 0.08262601389770959
#
#
# iteration: 41
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.47545331]
#  [0.80804986]
#  [0.78229365]
#  [0.87914323]]
# Loss:
# 0.08122578064528924
#
#
# iteration: 42
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.47106357]
#  [0.80916238]
#  [0.78377617]
#  [0.88041526]]
# Loss:
# 0.07984328358712056
#
#
# iteration: 43
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.46668906]
#  [0.81026653]
#  [0.78525758]
#  [0.88165936]]
# Loss:
# 0.07847907053786471
#
#
# iteration: 44
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.46233381]
#  [0.81136367]
#  [0.78673832]
#  [0.88287693]]
# Loss:
# 0.07713364252988544
#
#
# iteration: 45
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.45800149]
#  [0.81245495]
#  [0.78821862]
#  [0.88406921]]
# Loss:
# 0.07580745236736888
#
#
# iteration: 46
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.45369543]
#  [0.81354127]
#  [0.78969847]
#  [0.88523727]]
# Loss:
# 0.07450090386546214
#
#
# iteration: 47
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.44941864]
#  [0.81462336]
#  [0.79117768]
#  [0.88638208]]
# Loss:
# 0.07321435167295724
#
#
# iteration: 48
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.44517386]
#  [0.81570176]
#  [0.79265595]
#  [0.88750447]]
# Loss:
# 0.07194810159176919
#
#
# iteration: 49
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.44096356]
#  [0.8167769 ]
#  [0.79413284]
#  [0.88860523]]
# Loss:
# 0.07070241131791052
#
#
# iteration: 50
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.43678995]
#  [0.81784908]
#  [0.79560785]
#  [0.88968502]]
# Loss:
# 0.06947749153777592
#
#
# iteration: 51
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.43265503]
#  [0.81891847]
#  [0.79708039]
#  [0.89074449]]
# Loss:
# 0.06827350732099124
#
#
# iteration: 52
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.42856056]
#  [0.81998519]
#  [0.79854983]
#  [0.8917842 ]]
# Loss:
# 0.0670905797573341
#
#
# iteration: 53
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.42450813]
#  [0.82104926]
#  [0.80001552]
#  [0.89280468]]
# Loss:
# 0.0659287877906394
#
#
# iteration: 54
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.42049913]
#  [0.82211065]
#  [0.80147678]
#  [0.89380642]]
# Loss:
# 0.06478817020739913
#
#
# iteration: 55
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.41653476]
#  [0.82316927]
#  [0.80293293]
#  [0.89478988]]
# Loss:
# 0.06366872774211423
#
#
# iteration: 56
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.41261608]
#  [0.82422499]
#  [0.80438329]
#  [0.8957555 ]]
# Loss:
# 0.06257042526546021
#
#
# iteration: 57
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.408744  ]
#  [0.82527764]
#  [0.80582719]
#  [0.89670367]]
# Loss:
# 0.06149319402505866
#
#
# iteration: 58
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.40491928]
#  [0.82632703]
#  [0.80726397]
#  [0.89763481]]
# Loss:
# 0.06043693391213754
#
#
# iteration: 59
# Input:
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [1.]]
# Predicted Output:
# [[0.40114256]
#  [0.82737296]
#  [0.80869301]
#  [0.89854926]]
# Loss:
# 0.05940151573064189
